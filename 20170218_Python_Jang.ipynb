# %%
import numpy
from matplotlib import pyplot

# %%
x = numpy.loadtxt(fname='inflammation-01.csv', delimiter=',')

# %%
print("평균값 = ", x.mean())
print("최소값 = ", x.min())
print("최대값 = ", x.max())
# Out:
# 평균값 =  5.685
# 최소값 =  0.0
# 최대값 =  19.0

# %%
pyplot.figure()
pyplot.plot(x[0:2])
pyplot.show()
